# %% [markdown]
# # ***COVID -19: Case Study***

# %% [markdown]
# ### **Objective of the Case Study:** The primary objectives of this case study are:
# *  Practical Application of Python: To demonstrate and enhance practical skills in using Python for data analysis, focusing on data manipulation, cleaning, and visualization.
# *  Insightful Data Analysis: To provide analytical insights into the dynamics of COVID-19's spread, recovery, and mortality rates across different regions and over time.
# * Skill Development: To equip students with the knowledge to handle real-world data using Python libraries such as Pandas for data manipulation, Matplotlib for data visualization, and Numpy for numerical data processing.

# %%
import pandas as pd
import os

# %%
os.chdir(r'C:\Users\Admin\Desktop\Coding Ninjas\Python Classes\Case Study\COVID_19 CaseStudy')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\Desktop\\Coding Ninjas\\Python Classes\\Case Study\\COVID_19 CaseStudy'

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### ***Analysis Questions:***
# **1. Data Loading**: How do you load the COVID-19 datasets for confirmed cases, deaths, and recoveries into Python using Pandas?

# %%
# Loading excel files into Python - Jupyter notebook

confirmed = pd.read_excel(r'data/covid_19_dataset-1718175635.xlsx', sheet_name = 'covid_19_confirmed_v1')
recovered = pd.read_excel(r'data/covid_19_dataset-1718175635.xlsx', sheet_name = 'covid_19_recovered_v1')
deaths = pd.read_excel(r'data/covid_19_dataset-1718175635.xlsx', sheet_name = 'covid_19_deaths_v1')

# %% [markdown]
# ___

# %% [markdown]
# ***2. Data Exploration***
#
# **2(a)** After loading the datasets, what is the structure of each dataset in terms of rows, columns, and data types?

# %% [markdown]
# * Confirmed Cases Dataset: Contains the cumulative number of confirmed COVID-19 cases per day for each country and region. The data spans from January 22, 2020, to May 29, 2021, with over 276 geographic entries.

# %%
confirmed.head()
confirmed.shape
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    64575    65080    65486
# 1        0        0        0        0  ...   132118   132153   132176
# 2        0        0        0        0  ...   126156   126434   126651
# 3        0        0        0        0  ...    13569    13569    13569
# 4        0        0        0        0  ...    31661    31909    32149
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %% [markdown]
# * Recovered Cases Dataset: Includes data on the cumulative number of individuals who have recovered from COVID-19, which is vital for understanding the disease's progression and the effectiveness of treatment protocols.

# %%
recovered.head()
recovered.shape
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    55687    55790    55889
# 1        0        0        0        0  ...   127869   128425   128601
# 2        0        0        0        0  ...    87902    88066    88208
# 3        0        0        0        0  ...    13234    13234    13234
# 4        0        0        0        0  ...    26483    26513    26775
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %% [markdown]
# * Deaths Dataset: Records the cumulative number of deaths attributed to COVID-19, structured similarly to the confirmed cases dataset. This provides crucial information for assessing the lethality and outbreak severity in different areas.

# %%
deaths.head()
deaths.shape
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...     2772     2782     2792
# 1        0        0        0        0  ...     2440     2441     2442
# 2        0        0        0        0  ...     3401     3405     3411
# 3        0        0        0        0  ...      127      127      127
# 4        0        0        0        0  ...      704      709      715
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %%
# Information about the data
confirmed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Columns: 498 entries, Province/State to 5/29/21
# dtypes: float64(2), int64(494), object(2)
# memory usage: 1.0+ MB

# %%
# Describing the data
confirmed.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  274.000000  274.000000  276.000000  276.000000  276.000000  276.000000
# mean    20.447559   22.328281    2.018116    2.373188    3.409420    5.192029
# std     25.189838   74.369096   26.781738   26.879567   33.464159   46.575328
# min    -51.796300 -178.116500    0.000000    0.000000    0.000000    0.000000
# 25%      4.933349  -22.036550    0.000000    0.000000    0.000000    0.000000
# 50%     21.607878   20.921188    0.000000    0.000000    0.000000    0.000000
# 75%     40.950592   83.380449    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...       5/20/21  \
# count   276.000000   276.000000   276.000000   276.000000  ...  2.760000e+02
# mean      7.673913    10.605072    20.210145    22.344203  ...  5.984867e+05
# ...

# %%
# How to describe numerical and categorical columns separately.

# %%
confirmed.head()
# Out:
#   Province/State Country/Region       Lat       Long  1/22/20  1/23/20  \
# 0            NaN    Afghanistan  33.93911  67.709953        0        0
# 1            NaN        Albania  41.15330  20.168300        0        0
# 2            NaN        Algeria  28.03390   1.659600        0        0
# 3            NaN        Andorra  42.50630   1.521800        0        0
# 4            NaN         Angola -11.20270  17.873900        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 0        0        0        0        0  ...    64575    65080    65486
# 1        0        0        0        0  ...   132118   132153   132176
# 2        0        0        0        0  ...   126156   126434   126651
# 3        0        0        0        0  ...    13569    13569    13569
# 4        0        0        0        0  ...    31661    31909    32149
#
#    5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# ...

# %% [markdown]
# ***2. Data Exploration***
#
# **2(b)** Generate plots of confirmed cases over time for top countries.

# %%
confirmed.groupby('Country/Region')['5/29/21'].sum()
# Out:
# Country/Region
# Afghanistan            70111
# Albania               132297
# Algeria               128456
# Andorra                13693
# Angola                 34180
#                        ...
# Vietnam                 6908
# West Bank and Gaza    307838
# Yemen                   6731
# Zambia                 94751
# Zimbabwe               38933
# Name: 5/29/21, Length: 193, dtype: int64

# %%
top3 = confirmed.groupby('Country/Region')['5/29/21'].sum().nlargest(3)

# %%
top3
# Out:
# Country/Region
# US        33251939
# India     27894800
# Brazil    16471600
# Name: 5/29/21, dtype: int64

# %%
top3_countries = confirmed.groupby('Country/Region')['5/29/21'].sum().nlargest(3).index.tolist()

#Approach - 2
# top3_countries = confirmed.groupby('Country/Region')[cols[-1]].sum().nlargest(3).index.tolist()

# %%
top3_countries
# Out:
# ['US', 'India', 'Brazil']

# %% [markdown]
# ____

# %%
import matplotlib.pyplot as plt

# %%
confirmed.columns  = confirmed.columns.astype(str)

# %%
x = confirmed[confirmed['Country/Region'] == 'US'].columns[4:].tolist()

y = confirmed.loc[confirmed['Country/Region'] == 'US',x].values[0]

# %%
y
# Out:
# array([       1,        1,        2,        2,        5,        5,
#               5,        6,        6,        8,        8,        8,
#              11,       11,       11,       12,       12,       12,
#              12,       12,       13,       13,       14,       14,
#              14,       14,       14,       14,       14,       14,
#              16,       16,       16,       16,       16,       16,
#              17,       17,       25,       32,       55,       74,
#             107,      184,      237,      403,      519,      594,
#             782,     1147,     1586,     2219,     2978,     3212,
#            4679,     6512,     9169,    13663,    20030,    26025,
#           34898,    46136,    56755,    68837,    86693,   105383,
#          125013,   143912,   165987,   192301,   224560,   256792,
#          289087,   321477,   351354,   382747,   413516,   444731,
#          480667,   515081,   544183,   571440,   598380,   627205,
# ...

# %%
# Plot of covid confirmed cases of US from 2020 - 2021
plt.plot(x,y)

# %%
# Graph for top 3 countries of confirmed covid cases (2020-2021)
for country in top3_countries:
    x=confirmed[confirmed['Country/Region']==country].columns[4:].tolist()
    y=confirmed.loc[confirmed['Country/Region']==country,x].values[0]
    plt.plot(x,y)

# %% [markdown]
# ____
# ____

# %% [markdown]
# ____
# ____

# %%
import pandas as pd

# Create a small DataFrame with unique months for each product category and region

data = {

    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],  # Continuous unique months

    "Year": [2023, 2023, 2023, 2023, 2023, 2023],

    "Product Category": ["Electronics", "Electronics", "Electronics", "Furniture", "Furniture", "Furniture"],

    "Region": ["North America", "North America", "North America", "Europe", "Europe", "Europe"],

    "Sales": [50000, 52000, 54000, 30000, 32000, 34000],

    "Expenses": [30000, 31000, 32000, 20000, 21000, 22000]

}

# Create the DataFrame

data = pd.DataFrame(data)

print(data)
type(data)
# Out:
#   Month  Year Product Category         Region  Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000     30000
# 1   Feb  2023      Electronics  North America  52000     31000
# 2   Mar  2023      Electronics  North America  54000     32000
# 3   Apr  2023        Furniture         Europe  30000     20000
# 4   May  2023        Furniture         Europe  32000     21000
# 5   Jun  2023        Furniture         Europe  34000     22000
# pandas.core.frame.DataFrame

# %%
data.loc[0]
# Out:
# Month                         Jan
# Year                         2023
# Product Category      Electronics
# Region              North America
# Sales                       50000
# Expenses                    30000
# Name: 0, dtype: object

# %%
data.loc[data['Month']=='Apr']
type(data.loc[data['Month']=='Apr'])
# Out:
#   Month  Year Product Category  Region  Sales  Expenses
# 3   Apr  2023        Furniture  Europe  30000     20000
# pandas.core.frame.DataFrame

# %%
apr = data.loc[data['Month']=='Apr']
apr
type(apr)
# Out:
#   Month  Year Product Category  Region  Sales  Expenses
# 3   Apr  2023        Furniture  Europe  30000     20000
# pandas.core.frame.DataFrame

# %%
# Grab the data of Europe and reset the index; Look without resetting
data.loc[data['Region']=='Europe']
# Out:
#   Month  Year Product Category  Region  Sales  Expenses
# 3   Apr  2023        Furniture  Europe  30000     20000
# 4   May  2023        Furniture  Europe  32000     21000
# 5   Jun  2023        Furniture  Europe  34000     22000

# %%
#Display after resetting the index
data.loc[data['Region']=='Europe'].reset_index(drop = True)

type(data.loc[data['Region']=='Europe'].reset_index(drop = True))
# Out:
#   Month  Year Product Category  Region  Sales  Expenses
# 0   Apr  2023        Furniture  Europe  30000     20000
# 1   May  2023        Furniture  Europe  32000     21000
# 2   Jun  2023        Furniture  Europe  34000     22000
# pandas.core.frame.DataFrame

# %%
# Grabbing the Europe data 
data.loc[data['Region']=='Europe'].reset_index(drop = True).loc[1]

type(data.loc[data['Region']=='Europe'].reset_index(drop = True).loc[1])
# Out:
# Month                     May
# Year                     2023
# Product Category    Furniture
# Region                 Europe
# Sales                   32000
# Expenses                21000
# Name: 1, dtype: object
# pandas.core.series.Series

# %% [markdown]
# ____
# ____

# %%
# Daywise cases of US from Day-1 to Day-n with column and data

cols = confirmed.columns.tolist()
cols = cols[4:]
us = confirmed.loc[confirmed['Country/Region'] == 'US', cols]

# %%
#cols = confirmed.columns.tolist()
#cols[4:]

# %%
us
type(us)
# Out:
#      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  \
# 251        1        1        2        2        5        5        5        6
#
#      1/30/20  1/31/20  ...   5/20/21   5/21/21   5/22/21   5/23/21   5/24/21  \
# 251        6        8  ...  33056765  33085106  33104884  33117737  33143662
#
#       5/25/21   5/26/21   5/27/21   5/28/21   5/29/21
# 251  33166418  33190470  33217995  33239963  33251939
#
# [1 rows x 494 columns]
# pandas.core.frame.DataFrame

# %%
x = confirmed[confirmed['Country/Region'] == 'US'].columns[4:].tolist()

y = confirmed.loc[confirmed['Country/Region'] == 'US', x].values[0]

# %%
plt.plot(x,y)

# %%
# Graph for top 3 countries of confirmed covid cases (2020-2021)
for country in top3_countries:
    x=confirmed[confirmed['Country/Region']==country].columns[4:].tolist()
    y=confirmed.loc[confirmed['Country/Region']==country,x].values[0]
    plt.plot(x,y)

# %% [markdown]
# **2(c)** Generate plots of confirmed cases over time for China.

# %%
x = confirmed[confirmed['Country/Region'] == 'China'].columns[4:].tolist()

y = confirmed.loc[confirmed['Country/Region'] == 'China',x].sum()

# %%
#x

# %%
plt.plot(x,y)

# %%
aus = confirmed.loc[confirmed['Country/Region'] == 'Australia', x].sum()

# %%
plt.plot(x,aus)

# %% [markdown]
# ### Plot for every province in China

# %%
# It's trying to plot for every date which is wrong
cols = ['Province/State'] + x

china_frame = confirmed.loc[confirmed['Country/Region'] == 'China',cols]

# %%
china_frame.set_index('Province/State', drop=True).T.plot()
# Out:
# <Axes: >

# %%
# cols = ['Province/State'] + x

aus_frame = confirmed.loc[confirmed['Country/Region'] == 'Australia',cols]

# %%
aus_frame.set_index('Province/State', drop=True).T.plot()
# Out:
# <Axes: >

# %% [markdown]
# ___

# %%
import pandas as pd

import numpy as np

# Create a small DataFrame with unique months for each product category and region

data = {

    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],  # Continuous unique months

    "Year": [2023, 2023, 2023, 2023, 2023, 2023],

    "Product Category": ["Electronics", "Electronics", "Electronics", "Furniture", "Furniture", "Furniture"],

    "Region": ["North America", "North America", "North America", "Europe", "Europe", "Europe"],

    "Sales": [50000, 52000,np.nan , 30000, np.nan, 34000],

    "Expenses": [30000, np.nan, 32000, np.nan, 21000, 22000]

}

# Create the DataFrame

df = pd.DataFrame(data)

df
# Out:
#   Month  Year Product Category         Region    Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0       NaN
# 2   Mar  2023      Electronics  North America      NaN   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0       NaN
# 4   May  2023        Furniture         Europe      NaN   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0

# %%
df['Expenses'].isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# Name: Expenses, dtype: bool

# %%
df['Expenses'].isnull().sum()
# Out:
# 2

# %%
df.isnull()
# Out:
#    Month   Year  Product Category  Region  Sales  Expenses
# 0  False  False             False   False  False     False
# 1  False  False             False   False  False      True
# 2  False  False             False   False   True     False
# 3  False  False             False   False  False      True
# 4  False  False             False   False   True     False
# 5  False  False             False   False  False     False

# %%
df.isnull().sum()
# Out:
# Month               0
# Year                0
# Product Category    0
# Region              0
# Sales               2
# Expenses            2
# dtype: int64

# %%
###Sorting null values

# %%
df.isnull().sum().sort_values(ascending = True)
# Out:
# Month               0
# Year                0
# Product Category    0
# Region              0
# Sales               2
# Expenses            2
# dtype: int64

# %%
# Filling the null values

# %%
# Forward Filling of null values (ffill)

# Filling null values of Sales data with forward fill (ffill)

df['Sales'] = df['Sales'].fillna(method = 'ffill')
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\2553820952.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Sales'] = df['Sales'].fillna(method = 'ffill')
#   Month  Year Product Category         Region    Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0       NaN
# 2   Mar  2023      Electronics  North America  52000.0   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0       NaN
# 4   May  2023        Furniture         Europe  30000.0   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0

# %%
# Filling null values of Sales data with backward fill (bfill)

df['Expenses'] = df['Expenses'].fillna(method = 'bfill')
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\3626287606.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Expenses'] = df['Expenses'].fillna(method = 'bfill')
#   Month  Year Product Category         Region    Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0   32000.0
# 2   Mar  2023      Electronics  North America  52000.0   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0   21000.0
# 4   May  2023        Furniture         Europe  30000.0   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0

# %%
df['Sales'] = df['Sales'].fillna(df['Sales'].mean())
df
# Out:
#   Month  Year Product Category         Region    Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0   32000.0
# 2   Mar  2023      Electronics  North America  52000.0   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0   21000.0
# 4   May  2023        Furniture         Europe  30000.0   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0

# %%
df['Expenses'] = df['Expenses'].fillna(df['Expenses'].median())
df
# Out:
#   Month  Year Product Category         Region    Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0   32000.0
# 2   Mar  2023      Electronics  North America  52000.0   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0   21000.0
# 4   May  2023        Furniture         Europe  30000.0   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0

# %% [markdown]
# ____
# ____

# %% [markdown]
# ## ***Data Cleaning***

# %% [markdown]
# ### Checking the number of null values in the dataset

# %%
confirmed.isnull()
# Out:
#      Province/State  Country/Region    Lat   Long  1/22/20  1/23/20  1/24/20  \
# 0              True           False  False  False    False    False    False
# 1              True           False  False  False    False    False    False
# 2              True           False  False  False    False    False    False
# 3              True           False  False  False    False    False    False
# 4              True           False  False  False    False    False    False
# ..              ...             ...    ...    ...      ...      ...      ...
# 271            True           False  False  False    False    False    False
# 272            True           False  False  False    False    False    False
# 273            True           False  False  False    False    False    False
# 274            True           False  False  False    False    False    False
# 275            True           False  False  False    False    False    False
#
# ...

# %%
confirmed.isnull().sum().sort_values(ascending=False)
# Out:
# Province/State    190
# Lat                 2
# Long                2
# 12/18/20            0
# 12/13/20            0
#                  ...
# 6/28/20             0
# 6/27/20             0
# 6/26/20             0
# 6/25/20             0
# 5/29/21             0
# Length: 498, dtype: int64

# %%
recovered.isnull().sum().sort_values(ascending=False)
# Out:
# Province/State    191
# Lat                 1
# Long                1
# 4/20/20             1
# 12/19/20            0
#                  ...
# 6/29/20             0
# 6/28/20             0
# 6/27/20             0
# 6/26/20             0
# 5/29/21             0
# Length: 498, dtype: int64

# %%
deaths.isnull().sum().sort_values(ascending=False)
# Out:
# Province/State    190
# Lat                 2
# Long                2
# 4/20/20             1
# 12/19/20            0
#                  ...
# 6/29/20             0
# 6/28/20             0
# 6/27/20             0
# 6/26/20             0
# 5/29/21             0
# Length: 498, dtype: int64

# %% [markdown]
# ____

# %% [markdown]
# **3. Handling Missing Data:** Identify these missing values and replace them using a suitable imputation method such as forward filling for time-series data.

# %% [markdown]
# ## ***Filling the Null Data***

# %%
# Fill lat long null values using ffill

confirmed.loc[confirmed['Lat'].isnull()]
confirmed.loc[confirmed['Long'].isnull()]
# Out:
#             Province/State Country/Region  Lat  Long  1/22/20  1/23/20  \
# 52  Repatriated Travellers         Canada  NaN   NaN        0        0
# 88                 Unknown          China  NaN   NaN        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# 52        0        0        0        0  ...       13       13       13
# 88        0        0        0        0  ...        0        0        0
#
#     5/23/21  5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 52       13       13       13       13       13       13       13
# 88        0        0        0        0        0        0        0
#
# [2 rows x 498 columns]
#             Province/State Country/Region  Lat  Long  1/22/20  1/23/20  \
# 52  Repatriated Travellers         Canada  NaN   NaN        0        0
# 88                 Unknown          China  NaN   NaN        0        0
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  \
# ...

# %%
confirmed['Long'] = confirmed['Long'].fillna(method = 'ffill')
confirmed['Long'].isnull().sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\1243472951.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   confirmed['Long'] = confirmed['Long'].fillna(method = 'ffill')
# 0

# %%
confirmed['Lat'] = confirmed['Long'].fillna(method = 'ffill')
confirmed['Lat'].isnull().sum()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\3547899228.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   confirmed['Lat'] = confirmed['Long'].fillna(method = 'ffill')
# 0

# %%
recovered.loc[recovered['Lat'].isnull()]
recovered.loc[recovered['Long'].isnull()]
# Out:
#    Province/State Country/Region  Lat  Long  1/22/20  1/23/20  1/24/20  \
# 73        Unknown          China  NaN   NaN        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  5/23/21  \
# 73        0        0        0  ...       13        0       13       14
#
#     5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 73       14       10        9       13       14       10
#
# [1 rows x 498 columns]
#    Province/State Country/Region  Lat  Long  1/22/20  1/23/20  1/24/20  \
# 73        Unknown          China  NaN   NaN        0        0        0
#
#     1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  5/22/21  5/23/21  \
# 73        0        0        0  ...       13        0       13       14
#
#     5/24/21  5/25/21  5/26/21  5/27/21  5/28/21  5/29/21
# 73       14       10        9       13       14       10
#
# [1 rows x 498 columns]

# %%
# Home work - 

# Fill lat long null values using ffill

# Groupby, apply and transform

# %%
import pandas as pd

import numpy as np

 

# Create a small DataFrame with unique months for each product category and region

data = {

    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],  # Continuous unique months

    "Year": [2023, 2023, 2023, 2023, 2023, 2023],

    "Product Category": ["Electronics", "Electronics", "Electronics", "Furniture", "Furniture", "Furniture"],

    "Region": ["North America", "North America", "North America", "Europe", "Europe", "Europe"],

    "Sales": [50000, 52000,np.nan , 30000, np.nan, 34000],

    "Expenses": [30000, np.nan, 32000, np.nan, 21000, 22000]

}

# Create the DataFrame

df= pd.DataFrame(data)

df
# Out:
#   Month  Year Product Category         Region    Sales  Expenses
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0       NaN
# 2   Mar  2023      Electronics  North America      NaN   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0       NaN
# 4   May  2023        Furniture         Europe      NaN   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0

# %%
#df.groupby('Product Category')['Sales'].transform(np.mean)
df['Product_sales_mean'] = df.groupby('Product Category')['Sales'].transform(np.mean)
df
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\4152263065.py:2: FutureWarning: The provided callable <function mean at 0x000001C677ECE340> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df['Product_sales_mean'] = df.groupby('Product Category')['Sales'].transform(np.mean)
#   Month  Year Product Category         Region    Sales  Expenses  \
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0       NaN
# 2   Mar  2023      Electronics  North America      NaN   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0       NaN
# 4   May  2023        Furniture         Europe      NaN   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0
#
#    Product_sales_mean
# 0             51000.0
# 1             51000.0
# 2             51000.0
# 3             32000.0
# ...

# %%
# Impute sales null vales with Product wise mean

df['Sales'] = df['Sales'].fillna(df['Product_sales_mean'])
df
# Out:
#   Month  Year Product Category         Region    Sales  Expenses  \
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0       NaN
# 2   Mar  2023      Electronics  North America  51000.0   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0       NaN
# 4   May  2023        Furniture         Europe  32000.0   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0
#
#    Product_sales_mean
# 0             51000.0
# 1             51000.0
# 2             51000.0
# 3             32000.0
# 4             32000.0
# 5             32000.0

# %%
# Cumilative Sum

# %%
df.groupby('Product Category')['Sales'].cumsum()
# Out:
# 0     50000.0
# 1    102000.0
# 2    153000.0
# 3     30000.0
# 4     62000.0
# 5     96000.0
# Name: Sales, dtype: float64

# %%
# Cumsum for each region

df.groupby('Region')['Expenses'].cumsum()
# Out:
# 0    30000.0
# 1        NaN
# 2    62000.0
# 3        NaN
# 4    21000.0
# 5    43000.0
# Name: Expenses, dtype: float64

# %%
df
# Out:
#   Month  Year Product Category         Region    Sales  Expenses  \
# 0   Jan  2023      Electronics  North America  50000.0   30000.0
# 1   Feb  2023      Electronics  North America  52000.0       NaN
# 2   Mar  2023      Electronics  North America  51000.0   32000.0
# 3   Apr  2023        Furniture         Europe  30000.0       NaN
# 4   May  2023        Furniture         Europe  32000.0   21000.0
# 5   Jun  2023        Furniture         Europe  34000.0   22000.0
#
#    Product_sales_mean
# 0             51000.0
# 1             51000.0
# 2             51000.0
# 3             32000.0
# 4             32000.0
# 5             32000.0

# %%
df['Sales'].shift(1)
# Out:
# 0        NaN
# 1    50000.0
# 2    52000.0
# 3    51000.0
# 4    30000.0
# 5    32000.0
# Name: Sales, dtype: float64

# %% [markdown]
# _____
# _____

# %%
countries = ['Germany', 'Italy', 'France']

# %%
cols = confirmed.columns[4:].tolist()
country = 'Germany'
y = confirmed.loc[confirmed['Country/Region'] == country,cols].reset_index(drop=True).loc[0]
x = cols
plt.plot(x,y)

# %%
y = confirmed.loc[confirmed['Country/Region']==country, cols].reset_index(drop = True).sum().diff()

# %%
cols = confirmed.columns[4:].tolist()
for country in countries:
    x=cols
    y=confirmed.loc[confirmed['Country/Region']==country,cols].reset_index(drop = True).sum().diff()
    y[y<0] = 0
    plt.plot(x,y, label = country)
plt.legend()

# %%
confirmed.loc[confirmed['Country/Region']=='France', cols].reset_index(drop = True).sum().idxmax()
# Out:
# '5/19/21'

# %%
peak = {}
for country in countries:
    peak_value=confirmed.loc[confirmed['Country/Region']==country,cols].reset_index(drop = True).sum().idxmax()
    peak[country] = peak_value

# %%
peak
# Out:
# {'Germany': '5/29/21', 'Italy': '5/29/21', 'France': '5/19/21'}

# %%
# 1. Calculate Daily recovery cases

# 2. Calculate Daily confirmed cases

# 3. Divide and find for '12/31/20'

#cols = recovered.columns[4:].tolist()
recases = recovered.loc[recovered['Country/Region']=='Canada', '12/31/20'
recases = recovered.loc[recovered['Country/Region']=='Canada', '12/31/20'
# Out:
#   Cell In[225], line 8
#     recases = recovered.loc[recovered['Country/Region']=='Canada', '12/31/20'
#                                                                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
recovered.columns  = recovered.columns.astype(str)

# %%
deaths.columns  = deaths.columns.astype(str)

# %%
# Homework
# groupby, loc, melt

# %%
import pandas as pd

# Sample DataFrame

data = {

    'Region': ['North', 'North', 'South', 'South', 'East', 'East', 'West', 'West'],

    'Product': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],

    'Jan_2023': [1200, 1500, 900, 1150, 1000, 1300, 850, 1250],

    'Feb_2023': [1300, 1600, 950, 1200, 1050, 1350, 800, 1300],

    'Mar_2023': [1100, 1550, 870, 1180, 950, 1400, 900, 1275],

    'Apr_2023': [1400, 1650, 920, 1250, 1100, 1450, 950, 1320]

}

 
df = pd.DataFrame(data) 

# Using melt to transform the DataFrame

df_melted = pd.melt(df, id_vars=['Region', 'Product'], var_name='Month', value_name='Sales')

print(df_melted)
type(df_melted)
# Out:
#    Region Product     Month  Sales
# 0   North       A  Jan_2023   1200
# 1   North       B  Jan_2023   1500
# 2   South       A  Jan_2023    900
# 3   South       B  Jan_2023   1150
# 4    East       A  Jan_2023   1000
# 5    East       B  Jan_2023   1300
# 6    West       A  Jan_2023    850
# 7    West       B  Jan_2023   1250
# 8   North       A  Feb_2023   1300
# 9   North       B  Feb_2023   1600
# 10  South       A  Feb_2023    950
# 11  South       B  Feb_2023   1200
# 12   East       A  Feb_2023   1050
# 13   East       B  Feb_2023   1350
# 14   West       A  Feb_2023    800
# 15   West       B  Feb_2023   1300
# 16  North       A  Mar_2023   1100
# 17  North       B  Mar_2023   1550
# 18  South       A  Mar_2023    870
# 19  South       B  Mar_2023   1180
# 20   East       A  Mar_2023    950
# 21   East       B  Mar_2023   1400
# 22   West       A  Mar_2023    900
# 23   West       B  Mar_2023   1275
# 24  North       A  Apr_2023   1400
# 25  North       B  Apr_2023   1650
# ...

# %%
# Fill Na in 'Province/State' with 'All Provinces'

# Fill LAT & long with 0

# Convert the data to row dominant form

# %%
# deaths['Province/State'] = deaths['Province/State'].fillna('All Province/State')

# deaths['Lat'] = deaths['Lat'].fillna(0)  

# deaths['Long'] = deaths['Long'].fillna(0)  

# deaths_melted = pd.melt(deaths, id_vars=['Province/State','Country/Region','Lat','Long'], var_name='date', value_name='total_deaths')

# lolo = deaths_melted['date'].str.contains('-')

# deaths_melted['date'] = pd.to_datetime(deaths_melted['date'])

# deaths_melted.loc[lolo, 'date'] = pd.to_datetime(deaths_melted.loc[lolo, 'date'], format = '%m-%d-%Y')

# deaths_melted = deaths_melted.sort_values(by = ['date'])

# deaths_melted['daily_deaths']=deaths_melted.groupby(['Province/State','Country/Region'])['total_deaths'].diff()

# deaths_melted
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\3473912368.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   deaths_melted['date'] = pd.to_datetime(deaths_melted['date'])
#        Province/State Country/Region        Lat       Long       date  \
# 3035    All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-02
# 2859    All Provinces           Cuba  21.521757  21.521757 2020-01-02
# 2858    All Provinces        Croatia  45.100000  45.100000 2020-01-02
# 2857    All Provinces  Cote d'Ivoire   7.540000   7.540000 2020-01-02
# 2856    All Provinces     Costa Rica   9.748900   9.748900 2020-01-02
# ...               ...            ...        ...        ...        ...
# 131465       Xinjiang          China  41.112900  41.112900 2021-12-05
# 131464        Unknown          China   0.000000   0.000000 2021-12-05
# ...

# %%
# Fill Na in 'Province/State' with 'All Provinces'

deaths['Province/State'] = deaths['Province/State'].fillna("All Provinces")
deaths
# Out:
#     Province/State      Country/Region        Lat       Long  1/22/20  \
# 0    All Provinces         Afghanistan  33.939110  33.939110        0
# 1    All Provinces             Albania  41.153300  41.153300        0
# 2    All Provinces             Algeria  28.033900  28.033900        0
# 3    All Provinces             Andorra  42.506300  42.506300        0
# 4    All Provinces              Angola -11.202700 -11.202700        0
# ..             ...                 ...        ...        ...      ...
# 271  All Provinces             Vietnam  14.058324  14.058324        0
# 272  All Provinces  West Bank and Gaza  31.952200  31.952200        0
# 273  All Provinces               Yemen  15.552727  15.552727        0
# 274  All Provinces              Zambia -13.133897 -13.133897        0
# 275  All Provinces            Zimbabwe -19.015438 -19.015438        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/20/21  5/21/21  \
# ...

# %%
# Fill Lat & long with 0

deaths['Long'] = deaths['Lat'].fillna(0)
deaths['Long'] = deaths['Long'].fillna(0)

# Convert the data to row dominant form

deaths_melted = pd.melt(deaths, id_vars = ['Province/State', 'Country/Region', 'Lat', 'Long'], var_name='Date', value_name='DeathCases')
deaths_melted["Daily_Deaths"] = deaths_melted.groupby(['Province/State', 'Country/Region'])['DeathCases'].diff()
deaths_melted
# Out:
#        Province/State      Country/Region        Lat       Long     Date  \
# 0       All Provinces         Afghanistan  33.939110  33.939110  1/22/20
# 1       All Provinces             Albania  41.153300  41.153300  1/22/20
# 2       All Provinces             Algeria  28.033900  28.033900  1/22/20
# 3       All Provinces             Andorra  42.506300  42.506300  1/22/20
# 4       All Provinces              Angola -11.202700 -11.202700  1/22/20
# ...               ...                 ...        ...        ...      ...
# 136339  All Provinces             Vietnam  14.058324  14.058324  5/29/21
# 136340  All Provinces  West Bank and Gaza  31.952200  31.952200  5/29/21
# 136341  All Provinces               Yemen  15.552727  15.552727  5/29/21
# 136342  All Provinces              Zambia -13.133897 -13.133897  5/29/21
# 136343  All Provinces            Zimbabwe -19.015438 -19.015438  5/29/21
#
#         DeathCases  Daily_Deaths
# 0              0.0           NaN
# ...

# %%
#lolo = deaths_melted['Date'].str.contains('-')

deaths_melted['Date'] = pd.to_datetime(deaths_melted['Date'])


deaths_melted = deaths_melted.sort_values(by = ['Date'])

#deaths_melted['Daily_Deaths']=deaths_melted.groupby(['Province/State','Country/Region'])['DeathCases'].diff()

deaths_melted
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\932804033.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   deaths_melted['Date'] = pd.to_datetime(deaths_melted['Date'])
#        Province/State Country/Region        Lat       Long       Date  \
# 3035    All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-02
# 2859    All Provinces           Cuba  21.521757  21.521757 2020-01-02
# 2858    All Provinces        Croatia  45.100000  45.100000 2020-01-02
# 2857    All Provinces  Cote d'Ivoire   7.540000   7.540000 2020-01-02
# 2856    All Provinces     Costa Rica   9.748900   9.748900 2020-01-02
# ...               ...            ...        ...        ...        ...
# 131465       Xinjiang          China  41.112900  41.112900 2021-12-05
# 131464        Unknown          China   0.000000   0.000000 2021-12-05
# ...

# %%
# Country wise Daily_Deaths

deaths_melted.groupby('Country/Region')['Daily_Deaths'].sum()
# Out:
# Country/Region
# Afghanistan           2899.0
# Albania               2449.0
# Algeria               3443.0
# Andorra                127.0
# Angola                 757.0
#                        ...
# Vietnam                 47.0
# West Bank and Gaza    3492.0
# Yemen                 1319.0
# Zambia                1276.0
# Zimbabwe              1594.0
# Name: Daily_Deaths, Length: 193, dtype: float64

# %%
# Top 5 countries with avg daily deaths

deaths_melted.groupby('Country/Region')['Daily_Deaths'].mean().nlargest(5)
# Out:
# Country/Region
# US        1205.488844
# Brazil     935.206897
# India      661.200811
# Mexico     453.255578
# Italy      255.582150
# Name: Daily_Deaths, dtype: float64

# %%
# Homework

# %%
confirmed['Province/State'] = confirmed['Province/State'].fillna("All Provinces")
confirmed['Long'] = deaths['Lat'].fillna(0)
confirmed['Long'] = deaths['Long'].fillna(0)

confirmed_melted = pd.melt(confirmed, id_vars = ['Province/State', 'Country/Region', 'Lat', 'Long'], var_name='Date', value_name='Con_Cases')

# %%
confirmed_melted
# Out:
#        Province/State      Country/Region         Lat       Long     Date  \
# 0       All Provinces         Afghanistan   67.709953  33.939110  1/22/20
# 1       All Provinces             Albania   20.168300  41.153300  1/22/20
# 2       All Provinces             Algeria    1.659600  28.033900  1/22/20
# 3       All Provinces             Andorra    1.521800  42.506300  1/22/20
# 4       All Provinces              Angola   17.873900 -11.202700  1/22/20
# ...               ...                 ...         ...        ...      ...
# 136339  All Provinces             Vietnam  108.277199  14.058324  5/29/21
# 136340  All Provinces  West Bank and Gaza   35.233200  31.952200  5/29/21
# 136341  All Provinces               Yemen   48.516388  15.552727  5/29/21
# 136342  All Provinces              Zambia   27.849332 -13.133897  5/29/21
# 136343  All Provinces            Zimbabwe   29.154857 -19.015438  5/29/21
#
#         Con_Cases
# 0               0
# 1               0
# 2               0
# ...

# %%
recovered['Province/State'] = confirmed['Province/State'].fillna("All Provinces")
recovered['Long'] = deaths['Lat'].fillna(0)
recovered['Long'] = deaths['Long'].fillna(0)

# %%
recovered_melted = pd.melt(recovered, id_vars = ['Province/State', 'Country/Region', 'Lat', 'Long'], var_name='Date', value_name='Recovered_Cases')

# %%
recovered_melted['Date'] = pd.to_datetime(recovered_melted['Date'])
recovered_melted
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\1751256222.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   recovered_melted['Date'] = pd.to_datetime(recovered_melted['Date'])
#                      Province/State      Country/Region        Lat      Long  \
# 0                     All Provinces         Afghanistan  33.939110  33.93911
# 1                     All Provinces             Albania  41.153300  41.15330
# 2                     All Provinces             Algeria  28.033900  28.03390
# 3                     All Provinces             Andorra  42.506300  42.50630
# 4                     All Provinces              Angola -11.202700 -11.20270
# ...                             ...                 ...        ...       ...
# 128929                      Bermuda             Vietnam  14.058324  32.30780
# ...

# %%
confirmed_melted = confirmed_melted.sort_values(by = ['Date'])

confirmed_melted["Daily_Confirmed_Cases"] = confirmed_melted.groupby(['Province/State', 'Country/Region'])['Con_Cases'].diff()

confirmed_melted['Date'] = pd.to_datetime(confirmed_melted['Date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11920\1326979855.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   confirmed_melted['Date'] = pd.to_datetime(confirmed_melted['Date'])

# %%
recovered_melted = recovered_melted.sort_values(by = ['Date'])

recovered_melted["Daily_Recovered_Cases"] = recovered_melted.groupby(['Province/State', 'Country/Region'])['Recovered_Cases'].diff()

# %%
confirmed_melted
recovered_melted
deaths_melted
# Out:
#       Province/State    Country/Region         Lat       Long       Date  \
# 98739  All Provinces  Papua New Guinea  143.955550  -6.314993 2021-01-13
# 98706  All Provinces        Madagascar   46.869107 -18.766947 2021-01-13
# 98707  All Provinces            Malawi   34.301500 -13.254300 2021-01-13
# 98708  All Provinces          Malaysia  101.975766   4.210484 2021-01-13
# 98709  All Provinces          Maldives   73.220700   3.202800 2021-01-13
# ...              ...               ...         ...        ...        ...
# 69640        Unknown             China   88.092400   0.000000 2020-09-30
# 69639          Tibet             China   88.092400  31.692700 2020-09-30
# 69638        Tianjin             China  117.323000  39.305400 2020-09-30
# 69644  All Provinces          Colombia  -74.297300   4.570900 2020-09-30
# 69826  All Provinces            Zambia   27.849332 -13.133897 2020-09-30
#
#        Con_Cases  Daily_Confirmed_Cases
# 98739        833                    NaN
# ...

# %%
df_covid = confirmed_melted.merge(recovered_melted, on = ['Province/State', 'Country/Region', 'Lat', 'Long', 'Date'], how = 'outer')

# %% [markdown]
# ____

# %%
pip install sqlalchemy pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# dialect+connector://username:password@host:port/database

# %%
# Try it Later

from sqlalchemy import create_engine

from urllib.parse import quote_plus

import pandas as pd

# Encode the password

password = quote_plus('Welcome@123')

# Create the connection string with the encoded password

engine = create_engine(f'mysql+pymysql://root:{password}@localhost:3306/airbnb')

# Retrieve a table as a DataFrame

df = pd.read_sql('countries', con=engine)

# Display the df

df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:452, in Pool.connect(self)
#     445 """Return a DBAPI connection from the pool.
#     446
#     447 The connection is instrumented such that when its
#    (...)
# ...

# %%
import pandas as pd
# Sample DataFrame

data = {

    'Name': ['Alice Johnson', 'Bob Smith', 'Charlie Brown', 'David Lee', 'Eve Adams'],

    'Position': ['Manager', 'Team Lead', 'Developer', 'HR Specialist', 'Data Scientist'],

    'Department': ['Finance', 'Engineering', 'IT', 'Data Science', 'Data Analytics'],

    'Email': ['alice.johnson@company.com', 'bob.smith@company.com', 'charlie.brown@company.com', 

              'david.lee@company.com', 'eve.adams@company.com'],

    'Joining_Date': ['2021-01-15', '2019-05-20', '2018-07-30', '2020-03-11', '2022-08-23']

}

df = pd.DataFrame(data)

df['Joining_Date'] = pd.to_datetime(df['Joining_Date'])

# %%
df
# Out:
#             Name        Position      Department                      Email  \
# 0  Alice Johnson         Manager         Finance  alice.johnson@company.com
# 1      Bob Smith       Team Lead     Engineering      bob.smith@company.com
# 2  Charlie Brown       Developer              IT  charlie.brown@company.com
# 3      David Lee   HR Specialist    Data Science      david.lee@company.com
# 4      Eve Adams  Data Scientist  Data Analytics      eve.adams@company.com
#
#   Joining_Date
# 0   2021-01-15
# 1   2019-05-20
# 2   2018-07-30
# 3   2020-03-11
# 4   2022-08-23

# %%
df.loc[df['Department'].str.contains('Data')]
# Out:
#         Name        Position      Department                  Email  \
# 3  David Lee   HR Specialist    Data Science  david.lee@company.com
# 4  Eve Adams  Data Scientist  Data Analytics  eve.adams@company.com
#
#   Joining_Date
# 3   2020-03-11
# 4   2022-08-23

# %%
#Convert all the names into uppercase

df['Name'].str.upper()
# Out:
# 0    ALICE JOHNSON
# 1        BOB SMITH
# 2    CHARLIE BROWN
# 3        DAVID LEE
# 4        EVE ADAMS
# Name: Name, dtype: object

# %%
df['Name'].str.startswith('Alice')
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
# df['Name'].str.split().

# %%
df['Joining_Date'].dt.month
# Out:
# 0    1
# 1    5
# 2    7
# 3    3
# 4    8
# Name: Joining_Date, dtype: int32

# %%
df['Joining_Date'].dt.month_name()
# Out:
# 0    January
# 1        May
# 2       July
# 3      March
# 4     August
# Name: Joining_Date, dtype: object

# %%
dir(df['Joining_Date'])
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
import pandas as pd

 

# First DataFrame - Employee Information

data1 = {

    'Employee_ID': [101, 102, 103, 104, 105, 106],

    'Name': ['Alice Johnson', 'Bob Smith', 'Charlie Brown', 'David Lee', 'Eve Adams', 'Frank White'],

    'Department': ['Finance', 'Engineering', 'IT', 'Human Resources', 'Data Analytics', 'Marketing'],

    'Joining_Date': ['2021-01-15', '2019-05-20', '2018-07-30', '2020-03-11', '2022-08-23', '2023-04-10']

}
df1 = pd.DataFrame(data1)

df1['Joining_Date'] = pd.to_datetime(df1['Joining_Date']) 

# Second DataFrame - Employee Project Details

data2 = {

    'Employee_ID': [101, 102, 103, 107, 108],

    'Project': ['Project Alpha', 'Project Beta', 'Project Gamma', 'Project Delta', 'Project Epsilon'],

    'Hours_Worked': [120, 150, 80, 100, 90],

    'Team_Lead': ['John Doe', 'Jane Smith', 'Emily Davis', 'Michael Scott', 'Laura Adams']

}

df2 = pd.DataFrame(data2)

# %%
df1
df2
# Out:
#    Employee_ID           Name       Department Joining_Date
# 0          101  Alice Johnson          Finance   2021-01-15
# 1          102      Bob Smith      Engineering   2019-05-20
# 2          103  Charlie Brown               IT   2018-07-30
# 3          104      David Lee  Human Resources   2020-03-11
# 4          105      Eve Adams   Data Analytics   2022-08-23
# 5          106    Frank White        Marketing   2023-04-10
#    Employee_ID          Project  Hours_Worked      Team_Lead
# 0          101    Project Alpha           120       John Doe
# 1          102     Project Beta           150     Jane Smith
# 2          103    Project Gamma            80    Emily Davis
# 3          107    Project Delta           100  Michael Scott
# 4          108  Project Epsilon            90    Laura Adams

# %%
# Grab column project in df1 using inner join

df1.merge(df2[['Employee_ID', 'Project']], on = ['Employee_ID'], how = 'inner')
# Out:
#    Employee_ID           Name   Department Joining_Date        Project
# 0          101  Alice Johnson      Finance   2021-01-15  Project Alpha
# 1          102      Bob Smith  Engineering   2019-05-20   Project Beta
# 2          103  Charlie Brown           IT   2018-07-30  Project Gamma

# %%
df1.merge(df2[['Employee_ID', 'Project']], on = ['Employee_ID'], how = 'left')
# Out:
#    Employee_ID           Name       Department Joining_Date        Project
# 0          101  Alice Johnson          Finance   2021-01-15  Project Alpha
# 1          102      Bob Smith      Engineering   2019-05-20   Project Beta
# 2          103  Charlie Brown               IT   2018-07-30  Project Gamma
# 3          104      David Lee  Human Resources   2020-03-11            NaN
# 4          105      Eve Adams   Data Analytics   2022-08-23            NaN
# 5          106    Frank White        Marketing   2023-04-10            NaN

# %%
df1.merge(df2[['Employee_ID', 'Project']], on = ['Employee_ID'], how = 'right')
# Out:
#    Employee_ID           Name   Department Joining_Date          Project
# 0          101  Alice Johnson      Finance   2021-01-15    Project Alpha
# 1          102      Bob Smith  Engineering   2019-05-20     Project Beta
# 2          103  Charlie Brown           IT   2018-07-30    Project Gamma
# 3          107            NaN          NaN          NaT    Project Delta
# 4          108            NaN          NaN          NaT  Project Epsilon

# %%
df1.merge(df2[['Employee_ID', 'Project']], on = ['Employee_ID'], how = 'outer')
# Out:
#    Employee_ID           Name       Department Joining_Date          Project
# 0          101  Alice Johnson          Finance   2021-01-15    Project Alpha
# 1          102      Bob Smith      Engineering   2019-05-20     Project Beta
# 2          103  Charlie Brown               IT   2018-07-30    Project Gamma
# 3          104      David Lee  Human Resources   2020-03-11              NaN
# 4          105      Eve Adams   Data Analytics   2022-08-23              NaN
# 5          106    Frank White        Marketing   2023-04-10              NaN
# 6          107            NaN              NaN          NaT    Project Delta
# 7          108            NaN              NaN          NaT  Project Epsilon

# %% [markdown]
# ____
# ____

# %%
confirmed_melted
recovered_melted
deaths_melted
# Out:
#       Province/State    Country/Region         Lat       Long       Date  \
# 98739  All Provinces  Papua New Guinea  143.955550  -6.314993 2021-01-13
# 98706  All Provinces        Madagascar   46.869107 -18.766947 2021-01-13
# 98707  All Provinces            Malawi   34.301500 -13.254300 2021-01-13
# 98708  All Provinces          Malaysia  101.975766   4.210484 2021-01-13
# 98709  All Provinces          Maldives   73.220700   3.202800 2021-01-13
# ...              ...               ...         ...        ...        ...
# 69640        Unknown             China   88.092400   0.000000 2020-09-30
# 69639          Tibet             China   88.092400  31.692700 2020-09-30
# 69638        Tianjin             China  117.323000  39.305400 2020-09-30
# 69644  All Provinces          Colombia  -74.297300   4.570900 2020-09-30
# 69826  All Provinces            Zambia   27.849332 -13.133897 2020-09-30
#
#        Con_Cases  Daily_Confirmed_Cases
# 98739        833                    NaN
# ...

# %%
deaths_melted[deaths_melted['Country/Region'] == 'Zimbabwe']
# Out:
#        Province/State Country/Region        Lat       Long       Date  \
# 3035    All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-02
# 11039   All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-03
# 19595   All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-04
# 27875   All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-05
# 36431   All Provinces       Zimbabwe -19.015438 -19.015438 2020-01-06
# ...               ...            ...        ...        ...        ...
# 98531   All Provinces       Zimbabwe -19.015438 -19.015438 2021-12-01
# 107087  All Provinces       Zimbabwe -19.015438 -19.015438 2021-12-02
# 114815  All Provinces       Zimbabwe -19.015438 -19.015438 2021-12-03
# 123371  All Provinces       Zimbabwe -19.015438 -19.015438 2021-12-04
# 131651  All Provinces       Zimbabwe -19.015438 -19.015438 2021-12-05
#
#         DeathCases  Daily_Deaths
# 3035           0.0           0.0
# 11039          0.0           0.0
# ...

# %%
# lolo = deaths_melted['Date'].str.contains('-')

# deaths_melted['Date'] = pd.to_datetime(deaths_melted['date'])

# deaths_melted.loc[lolo, 'Date'] = pd.to_datetime(deaths_melted.loc[lolo, 'date'], format = '%m-%d-%Y')

# %%
combined_data  = deaths_melted.merge(recovered_melted[['Province/State', 'Country/Region', 'Date', 'Daily_Recovered_Cases']], on = ['Province/State', 'Country/Region', 'Date'], how = 'outer')
combined_data
# Out:
#        Province/State    Country/Region        Lat       Long       Date  \
# 0       All Provinces          Zimbabwe -19.015438 -19.015438 2020-01-02
# 1       All Provinces              Cuba  21.521757  21.521757 2020-01-02
# 2       All Provinces           Croatia  45.100000  45.100000 2020-01-02
# 3       All Provinces     Cote d'Ivoire   7.540000   7.540000 2020-01-02
# 4       All Provinces        Costa Rica   9.748900   9.748900 2020-01-02
# ...               ...               ...        ...        ...        ...
# 176847          Tibet           Denmark        NaN        NaN 2021-12-05
# 176848        Unknown           Denmark        NaN        NaN 2021-12-05
# 176849       Xinjiang           Denmark        NaN        NaN 2021-12-05
# 176850         Yunnan  Diamond Princess        NaN        NaN 2021-12-05
# 176851       Zhejiang          Djibouti        NaN        NaN 2021-12-05
#
#         DeathCases  Daily_Deaths  Daily_Recovered_Cases
# ...

# %%
combined_data = combined_data.merge(confirmed_melted[['Province/State', 'Country/Region', 'Date', 'Daily_Confirmed_Cases']], on = ['Province/State', 'Country/Region', 'Date'], how = 'outer')
combined_data
# Out:
#        Province/State    Country/Region        Lat       Long       Date  \
# 0       All Provinces          Zimbabwe -19.015438 -19.015438 2020-01-02
# 1       All Provinces              Cuba  21.521757  21.521757 2020-01-02
# 2       All Provinces           Croatia  45.100000  45.100000 2020-01-02
# 3       All Provinces     Cote d'Ivoire   7.540000   7.540000 2020-01-02
# 4       All Provinces        Costa Rica   9.748900   9.748900 2020-01-02
# ...               ...               ...        ...        ...        ...
# 176847          Tibet           Denmark        NaN        NaN 2021-12-05
# 176848        Unknown           Denmark        NaN        NaN 2021-12-05
# 176849       Xinjiang           Denmark        NaN        NaN 2021-12-05
# 176850         Yunnan  Diamond Princess        NaN        NaN 2021-12-05
# 176851       Zhejiang          Djibouti        NaN        NaN 2021-12-05
#
#         DeathCases  Daily_Deaths  Daily_Recovered_Cases  \
# ...

# %%
# To display only required columns of dataframe in pandas
dist_demo.loc[:,['State', 'District', 'Population']]
